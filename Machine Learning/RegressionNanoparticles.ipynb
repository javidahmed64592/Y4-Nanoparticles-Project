# %% [markdown]
# ## **Using a Convolutional Neural Network to Identify Cube Rotations.**

# %% [markdown]
# In this notebook, I will be using images which I have generated using my Shape3D.py and GenerateData.py images, found at https://github.com/javidahmed64592/Y4-Nanoparticles-Project.
#
# I will be using TensorFlow2 and Keras to create a Sequential model which will be trained using the cube images, and then more images will be tested to see if the model can correctly identify their rotations.
#
# The tutorial I followed can be found at https://www.tensorflow.org/tutorials/images/classification.

# %% [markdown]
# # Importing the relevant libraries.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import json
import PIL
from scipy.spatial.transform import Rotation as R

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# # Creating the dataset.

# %% [markdown]
# Retrieving images.

# %%
from google.colab import drive
drive.mount('/content/drive')

folder_name = "Cubes Unmoving"
direc = os.path.join("/content/drive/MyDrive/Nanoparticles/", folder_name)
# Out:
# Mounted at /content/drive

# %% [markdown]
# First, the images to be used for training must be assigned to the training subset. I will be using 80% to train, and 20% to validate. The images are loaded in using PIL and converted to NumPy arrays.

# %%
def load_imgs_from_path(folder_path):
  imgs = []
  img_names = []
  labels = []
  
  for rotation in os.listdir(folder_path):
    rotation_path = os.path.join(folder_path, rotation)
    label = json.loads(rotation)
    for image_name in os.listdir(rotation_path):
      labels.append(label)
      img = PIL.Image.open(os.path.join(rotation_path, image_name)).convert('L')

      brightness_enhance = PIL.ImageEnhance.Brightness(img)
      img = brightness_enhance.enhance(np.random.uniform(0.4, 2))

      contrast_enhance = PIL.ImageEnhance.Contrast(img)
      img = contrast_enhance.enhance(np.random.uniform(0.4, 2))

      sharpness_enhance = PIL.ImageEnhance.Sharpness(img)
      img = sharpness_enhance.enhance(np.random.uniform(0.4, 2))

      img_array = np.array(img)
      imgs.append(img_array)
      img_names.append(image_name)

  imgs = np.array(imgs)
  imgs = imgs.reshape(*imgs.shape, 1)

  return np.array(imgs), np.array(img_names), np.array(labels)

# %%
training_path = os.path.join(direc, "Train")
validation_path = os.path.join(direc, "Valid")
testing_path = os.path.join(direc, "Test")

train_imgs, train_names, train_labels = load_imgs_from_path(training_path)
valid_imgs, valid_names, valid_labels = load_imgs_from_path(validation_path)
test_imgs, test_names, test_labels = load_imgs_from_path(testing_path)

# %% [markdown]
# TensorFlow

# %%
img_size = [64, 64]

train_augmentation = keras.Sequential(
  [
    layers.Resizing(*img_size),
    layers.Rescaling(1./255),
    layers.RandomFlip("horizontal", input_shape=(*img_size, 1)),
    #layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

test_augmentation = keras.Sequential(
  [
    layers.Resizing(*img_size),
    layers.Rescaling(1./255),
  ]
)

# %%
def create_dataset(imgs, labels, aug, batch_size):
  dataset = tf.data.Dataset.from_tensor_slices((imgs, labels))
  dataset = (
    dataset
    .shuffle(batch_size * 10)
    .batch(batch_size)
    .map(lambda x, y: (aug(x), y),
      num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
  )
  return dataset

batch_size = 32

# %%
train_dataset = create_dataset(train_imgs, train_labels, train_augmentation, batch_size)
valid_dataset = create_dataset(valid_imgs, valid_labels, train_augmentation, batch_size)
test_dataset = create_dataset(test_imgs, test_labels, test_augmentation, batch_size)

# %% [markdown]
# Using data augmentation adds some more variety to the training data, thus resulting in a higher accuracy.

# %% [markdown]
# # Creating the model.

# %%
def get_model(n_inputs, n_outputs):
  model = Sequential([
    layers.Conv2D(16, 3, padding='same', activation='relu', input_shape=(*img_size, 1)),
    layers.MaxPooling2D(pool_size=2, strides=2),
    layers.Conv2D(32, 3, padding='same', activation='relu', input_shape=(*img_size, 1)),
    layers.MaxPooling2D(pool_size=2, strides=2),
    layers.Conv2D(64, 3, padding='same', activation='relu', input_shape=(*img_size, 1)),
    layers.MaxPooling2D(pool_size=2, strides=2),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(img_size[0], input_dim=n_inputs, activation='relu'),
    layers.Dense(img_size[0] * 2, input_dim=n_inputs, activation='relu'),
    layers.Dense(img_size[0] * 4, input_dim=n_inputs, activation='relu'),
    layers.Dense(img_size[0] * 2, input_dim=n_inputs, activation='relu'),
    layers.Dense(img_size[0], input_dim=n_inputs, activation='relu'),
    layers.Dense(n_outputs, activation="tanh")
  ])

  return model

# %% [markdown]
# Creating and compiling the model.

# %%
model = get_model(train_imgs.shape[1], train_labels.shape[1])

model.compile(optimizer='adam',
              loss='mae',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_47 (Conv2D)          (None, 64, 64, 16)        160
#
#  max_pooling2d_47 (MaxPoolin  (None, 32, 32, 16)       0
#  g2D)
#
#  conv2d_48 (Conv2D)          (None, 32, 32, 32)        4640
#
#  max_pooling2d_48 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_49 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 8, 8, 64)          0
#
#  flatten_16 (Flatten)        (None, 4096)              0
#
#  dense_89 (Dense)            (None, 64)                262208
#
#  dense_90 (Dense)            (None, 128)               8320
#
#  dense_91 (Dense)            (None, 256)               33024
#
#  dense_92 (Dense)            (None, 128)               32896
#
#  dense_93 (Dense)            (None, 64)                8256
#
#  dense_94 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 368,390
# Trainable params: 368,390
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training the model.

# %%
epochs = 50
history = model.fit(
  train_dataset,
  validation_data=valid_dataset,
  epochs=epochs,
)
# Out:
# Epoch 1/50
# 90/90 [==============================] - 13s 139ms/step - loss: 0.1332 - accuracy: 0.6448 - val_loss: 0.1568 - val_accuracy: 0.6250
# Epoch 2/50
# 90/90 [==============================] - 12s 138ms/step - loss: 0.1158 - accuracy: 0.6264 - val_loss: 0.1534 - val_accuracy: 0.6250
# Epoch 3/50
# 90/90 [==============================] - 12s 139ms/step - loss: 0.1024 - accuracy: 0.7198 - val_loss: 0.1341 - val_accuracy: 0.6250
# Epoch 4/50
# 90/90 [==============================] - 12s 137ms/step - loss: 0.0770 - accuracy: 0.6767 - val_loss: 0.1196 - val_accuracy: 0.6250
# Epoch 5/50
# 90/90 [==============================] - 12s 137ms/step - loss: 0.0804 - accuracy: 0.5726 - val_loss: 0.1187 - val_accuracy: 0.7500
# Epoch 6/50
# 90/90 [==============================] - 12s 139ms/step - loss: 0.0765 - accuracy: 0.6337 - val_loss: 0.1261 - val_accuracy: 0.7500
# Epoch 7/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0872 - accuracy: 0.7479 - val_loss: 0.1123 - val_accuracy: 0.7514
# Epoch 8/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0865 - accuracy: 0.7635 - val_loss: 0.1063 - val_accuracy: 0.7500
# Epoch 9/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0833 - accuracy: 0.7705 - val_loss: 0.1038 - val_accuracy: 0.7569
# Epoch 10/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0811 - accuracy: 0.7670 - val_loss: 0.1020 - val_accuracy: 0.7917
# Epoch 11/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0778 - accuracy: 0.7635 - val_loss: 0.1059 - val_accuracy: 0.7514
# Epoch 12/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0863 - accuracy: 0.7632 - val_loss: 0.0934 - val_accuracy: 0.7514
# Epoch 13/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0743 - accuracy: 0.7740 - val_loss: 0.1011 - val_accuracy: 0.7556
# Epoch 14/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0859 - accuracy: 0.7462 - val_loss: 0.0954 - val_accuracy: 0.7736
# Epoch 15/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0891 - accuracy: 0.7590 - val_loss: 0.1012 - val_accuracy: 0.7889
# Epoch 16/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0861 - accuracy: 0.7830 - val_loss: 0.0909 - val_accuracy: 0.7694
# Epoch 17/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0760 - accuracy: 0.7962 - val_loss: 0.0893 - val_accuracy: 0.7750
# Epoch 18/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0697 - accuracy: 0.7965 - val_loss: 0.1003 - val_accuracy: 0.8056
# Epoch 19/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0828 - accuracy: 0.7917 - val_loss: 0.0899 - val_accuracy: 0.7514
# Epoch 20/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0780 - accuracy: 0.7990 - val_loss: 0.0858 - val_accuracy: 0.7514
# Epoch 21/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0735 - accuracy: 0.8000 - val_loss: 0.0871 - val_accuracy: 0.8264
# Epoch 22/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0710 - accuracy: 0.8059 - val_loss: 0.0881 - val_accuracy: 0.8083
# Epoch 23/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0664 - accuracy: 0.8351 - val_loss: 0.0874 - val_accuracy: 0.8194
# Epoch 24/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0632 - accuracy: 0.8403 - val_loss: 0.0735 - val_accuracy: 0.8556
# Epoch 25/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0562 - accuracy: 0.8656 - val_loss: 0.0699 - val_accuracy: 0.8667
# Epoch 26/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0558 - accuracy: 0.8615 - val_loss: 0.0773 - val_accuracy: 0.8958
# Epoch 27/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0509 - accuracy: 0.8767 - val_loss: 0.0644 - val_accuracy: 0.9097
# Epoch 28/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0434 - accuracy: 0.8663 - val_loss: 0.0611 - val_accuracy: 0.9389
# Epoch 29/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0426 - accuracy: 0.8830 - val_loss: 0.0541 - val_accuracy: 0.9528
# Epoch 30/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0409 - accuracy: 0.9014 - val_loss: 0.0506 - val_accuracy: 0.9542
# Epoch 31/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0368 - accuracy: 0.9104 - val_loss: 0.0358 - val_accuracy: 0.9611
# Epoch 32/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0324 - accuracy: 0.9080 - val_loss: 0.0319 - val_accuracy: 0.9014
# Epoch 33/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0290 - accuracy: 0.9201 - val_loss: 0.0262 - val_accuracy: 0.9125
# Epoch 34/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0265 - accuracy: 0.9042 - val_loss: 0.0315 - val_accuracy: 0.9167
# Epoch 35/50
# 90/90 [==============================] - 12s 134ms/step - loss: 0.0279 - accuracy: 0.9024 - val_loss: 0.0245 - val_accuracy: 0.9014
# Epoch 36/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0251 - accuracy: 0.9302 - val_loss: 0.0207 - val_accuracy: 0.9222
# Epoch 37/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0213 - accuracy: 0.9003 - val_loss: 0.0227 - val_accuracy: 0.9000
# Epoch 38/50
# 90/90 [==============================] - 12s 137ms/step - loss: 0.0204 - accuracy: 0.8997 - val_loss: 0.0172 - val_accuracy: 0.9014
# Epoch 39/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0177 - accuracy: 0.9038 - val_loss: 0.0150 - val_accuracy: 0.9042
# Epoch 40/50
# 90/90 [==============================] - 12s 134ms/step - loss: 0.0149 - accuracy: 0.9108 - val_loss: 0.0149 - val_accuracy: 0.8972
# Epoch 41/50
# 90/90 [==============================] - 12s 134ms/step - loss: 0.0136 - accuracy: 0.9014 - val_loss: 0.0128 - val_accuracy: 0.9000
# Epoch 42/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0126 - accuracy: 0.9059 - val_loss: 0.0125 - val_accuracy: 0.8681
# Epoch 43/50
# 90/90 [==============================] - 12s 134ms/step - loss: 0.0103 - accuracy: 0.9142 - val_loss: 0.0096 - val_accuracy: 0.9111
# Epoch 44/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0097 - accuracy: 0.9000 - val_loss: 0.0111 - val_accuracy: 0.9042
# Epoch 45/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0111 - accuracy: 0.9052 - val_loss: 0.0101 - val_accuracy: 0.8722
# Epoch 46/50
# 90/90 [==============================] - 12s 135ms/step - loss: 0.0120 - accuracy: 0.9035 - val_loss: 0.0112 - val_accuracy: 0.8875
# Epoch 47/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0101 - accuracy: 0.9181 - val_loss: 0.0097 - val_accuracy: 0.9347
# Epoch 48/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0101 - accuracy: 0.9201 - val_loss: 0.0096 - val_accuracy: 0.9375
# Epoch 49/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0084 - accuracy: 0.9267 - val_loss: 0.0085 - val_accuracy: 0.8764
# Epoch 50/50
# 90/90 [==============================] - 12s 136ms/step - loss: 0.0086 - accuracy: 0.9056 - val_loss: 0.0078 - val_accuracy: 0.8722

# %% [markdown]
# Visualizing the training results.

# %%
acc = np.array(history.history['accuracy'])
val_acc = np.array(history.history['val_accuracy'])

loss = np.array(history.history['loss'])
val_loss = np.array(history.history['val_loss'])

epochs_range = range(epochs)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc * 100, label='Training Accuracy')
plt.plot(epochs_range, val_acc * 100, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.xlabel("Epoch number")
plt.ylabel("Percentage accuracy")
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.xlabel("Epoch number")
plt.ylabel("Loss")
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Predicting an image.

# %%
def predict_image(prediction, img_name):
  name = img_name.split()
  actual_rx = name[2][2:]
  actual_ry = name[3][2:]
  actual_rz = name[4][2:]

  actual_euler = np.array([int(actual_rx), int(actual_ry), int(actual_rz)])

  rotation = np.array(prediction).reshape((2, 3)).T
  v1 = rotation[:, 0]
  v2 = rotation[:, 1]

  e1 = v1 / np.linalg.norm(v1)

  u2 = v2 - ((e1 * v2) * e1)
  e2 = u2 / np.linalg.norm(u2)

  e3 = np.cross(e1, e2) 

  rotation = np.vstack((e1, e2, e3)).T
  rotation_euler = R.from_matrix(rotation).as_euler('xyz', degrees=True)

  # print("Actual: \t%s \t| Predicted: \t%s \t| Difference: \t%s" % (actual_euler, np.round(rotation_euler, 1), np.round(rotation_euler-actual_euler, 1)))

  return (rotation_euler - actual_euler, actual_euler.tolist())

# %%
predictions = model.predict(test_dataset)

# %%
dr = []
ae = []

for index in range(len(predictions)):
  results = predict_image(predictions[index], test_names[index])
  dr.append(results[0])
  if results[1] not in ae:
    ae.append(results[1])

dr = np.array(dr)

# %% [markdown]
# Visualising how accurately the model predicts rotations.

# %%
num_rots = len(ae)
imgs_per_rot = test_imgs.shape[0] / num_rots

dr = dr.reshape((num_rots, int(test_imgs.shape[0] / num_rots), 3))

# %%
for index in range(dr.shape[0]):
  rot_set = dr[index]
  x = np.arange(rot_set.shape[0]) + 1

  plt.figure(figsize=(15, 6))
  plt.subplot(111)
  plt.plot(x, rot_set[:,0], label="Difference in rx")
  plt.plot(x, rot_set[:,1], label="Difference in ry")
  plt.plot(x, rot_set[:,2], label="Difference in rz")
  plt.hlines(0, x[0], x[-1])
  plt.ylabel("Difference in angle")
  plt.xlim([x[0], x[-1]])
  plt.ylim([-50, 50])
  plt.legend(loc="best")
  plt.title("Model Predictions | %s" % ae[index])

plt.xlabel("Image No.")
plt.show()
